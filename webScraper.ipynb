# %%
import requests
import spacy
import re
import pandas as pd
import csv
import time
from datetime import datetime, timedelta, date
from bs4 import BeautifulSoup
from urllib.parse import urlparse
from collections import Counter
import warnings
warnings.filterwarnings("ignore")
# Out:
# C:\Users\reime\AppData\Local\Temp\ipykernel_15700\3319199840.py:4: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
nlp = spacy.load("en_core_web_sm")
#THIS PART GETS THE COMPANY NAME AND DOMAIN!
# Load keywords from the Excel file
try:
    keywords_df = pd.read_excel("Ransomware_List.xlsx")
    ransomware_group = keywords_df['Ransomware Group'].str.lower()
except Exception as e:
    print("An error occurred while loading the keywords file:", str(e))
    ransomware_group = []

# Additional keywords to exclude
additional_keywords = ['databreaches', 'the office of inadequate security']

# Define a custom pattern for organization names with hyphenated, dashed, or numbers
custom_pattern = re.compile(r'\b(?:[A-Za-z0-9]+[-\s]?)+[A-Za-z0-9]+\b')

def extract_company_domain(html_content, company_name):
    soup = BeautifulSoup(html_content, 'html.parser')

    # Extract href links
    href_links = [a['href'] for a in soup.find_all('a', href=True)]

    # Filter links that contain the company name and exclude specific keywords
    if company_name is not None:
        filtered_links = [link for link in href_links if re.search(r'\b{}\b'.format(re.escape(company_name)), link, re.IGNORECASE) and not any(keyword in link.lower() for keyword in additional_keywords)]
    else:
        filtered_links = []

    # Extract domain from filtered links
    domains = [urlparse(link).netloc for link in filtered_links]

    return domains[0] if domains else None

def extract_company_info(html_content):
    soup = BeautifulSoup(html_content, 'html.parser')

    # Extract title, h1, and p elements with a specific class
    title = soup.title.text.strip() if soup.title else ""

    # Exclude h3 tags and any text within <a> tags
    div_text = ' '.join([div.text.strip() for div in soup.find_all(['div', 'p'], class_='entry-content') if div.name not in ['h3'] and not div.find('a')])

    # Concatenate title, h1, and p text
    combined_text = f"{title} {div_text}"

    # Process the combined text with spaCy's NER
    doc = nlp(combined_text)

    # Extract entities that are likely to be organizations (ORG) and include dashes, hyphens, and numbers
    organizations_ner = [ent.text for ent in doc.ents if ent.label_ == 'ORG' and all(word[0].isupper() for word in ent.text.split())]

    # Add organizations matching the custom pattern
    organizations_custom_pattern = custom_pattern.findall(combined_text)

    # Capitalize the first letter of each word in organizations from the custom pattern
    organizations_custom_pattern = [' '.join(word.capitalize() for word in org.split()) for org in organizations_custom_pattern]

    # Combine organizations from NER and custom pattern
    organizations = organizations_ner + organizations_custom_pattern

    # Exclude organizations containing specific keywords
    filtered_organizations = [org for org in organizations if not any(keyword in org.lower() for keyword in ransomware_group)] + [org for org in organizations if any(keyword in org.lower() for keyword in additional_keywords)]

    company_name = filtered_organizations[0] if filtered_organizations else None

    # Extract company domain
    company_domain = extract_company_domain(html_content, company_name)

    return company_name, company_domain

# %%
#THIS PART GETS THE THREAT ACTOR/RANSOMWARE USED
def find_ransomware_group(html_content, ransomware_groups):
    soup = BeautifulSoup(html_content, 'html.parser')

    # Exclude div elements with class 'crp_related crp-text-only' and their descendants
    divs_to_exclude = soup.find_all('div', class_='crp_related crp-text-only')
    for div_to_exclude in divs_to_exclude:
        div_to_exclude.decompose()  # Remove the div and its descendants from the soup

    # Extract title and div text
    title = soup.title.text.strip() if soup.title else ""

    # Extract text from divs excluding text within anchor links
    div_text = ' '.join([div.text.strip() for div in soup.find_all('div', class_='entry-content') if not div.find('a')])

    # Concatenate title and div text
    combined_text = f"{title} {div_text}"

    # Convert both combined_text and ransomware group names to lowercase for case-insensitive comparison
    combined_text_lower = combined_text.lower()
    ransomware_groups_lower = [group.lower() for group in ransomware_groups]

    # Check for ransomware groups in the combined text with word boundaries
    for group, group_lower in zip(ransomware_groups, ransomware_groups_lower):
        if re.search(fr'\b{re.escape(group_lower)}\b', combined_text_lower):
            return group

    # If no match is found, default to 'ransomware'
    return 'Ransomware'

# Load ransomware groups from Excel file
def load_ransomware_groups(file_path):
    try:
        df = pd.read_excel(file_path)
        return df['Ransomware Group'].tolist()
    except Exception as e:
        print("Error loading ransomware groups:", str(e))
        return []

excel_file_path = 'Ransomware_List.xlsx'

# Load ransomware groups
ransomware_groups = load_ransomware_groups(excel_file_path)

# %%
#THIS PART GETS THE COMPANY'S INDUSTRY
def load_industry_keywords(file_path):
    try:
        df = pd.read_excel(file_path)
        return df
    except Exception as e:
        print("Error loading industry keywords:", str(e))
        return pd.DataFrame()

def extract_company_industry(html_content, industry_keywords):
    soup = BeautifulSoup(html_content, 'html.parser')

    # Extract title and div text, excluding div with class 'crp_related crp-text-only' and its descendants
    title = soup.title.text.strip() if soup.title else ""
    divs_to_exclude = soup.find_all('div', class_='crp_related crp-text-only')
    for div_to_exclude in divs_to_exclude:
        div_to_exclude.decompose()  # Remove the div and its descendants from the soup

    div_text = ' '.join([div.text.strip() for div in soup.find_all('div', class_='entry-content')])

    # Concatenate title and div text
    combined_text = f"{title} {div_text}"

    # Convert both combined_text and industry keywords to lowercase for case-insensitive comparison
    combined_text_lower = combined_text.lower()

    # Check for industry keywords in the combined text
    for index, row in industry_keywords.iterrows():
        industry = row['Industry']
        subcategory = row['Subcategory']
        industry_lower = industry.lower()
        subcategory_lower = subcategory.lower()

        # Use word boundaries in regex for whole word matching
        word_boundary_industry = rf'\b{re.escape(industry_lower)}\b'
        word_boundary_subcategory = rf'\b{re.escape(subcategory_lower)}\b'

        if re.search(word_boundary_subcategory, combined_text_lower):
            return industry

        if re.search(word_boundary_industry, combined_text_lower):
            return industry

    # If no match is found, default to 'Unknown'
    return 'Unknown'

excel_file_path = 'Industry_List.xlsx'

# Load industry keywords
industry_keywords = load_industry_keywords(excel_file_path)

# %%
#THIS PART GETS THE DATE OF BREACH
def extract_dates(html_content):
    soup = BeautifulSoup(html_content, 'html.parser')

    # Remove specified div elements
    divs_to_exclude = soup.find_all('div', class_='crp_related crp-text-only')
    for div_to_exclude in divs_to_exclude:
        div_to_exclude.decompose()

    # Extract the text from the remaining div
    div_text = ' '.join([div.text.strip() for div in soup.find_all('div', class_='entry-content')])

    # Process the text with NER
    doc = nlp(div_text)

    # Extract dates from the NER results
    dates = []
    for ent in doc.ents:
        if ent.label_ == 'DATE':
            dates.append(ent.text)

    # Extract partial dates using regular expressions
    partial_dates = re.findall(r'\b(?:January|February|March|April|May|June|July|August|September|October|November|December)?\b\s?(?:\d{4})?\b', div_text)

    # Combine the extracted dates and partial dates
    all_dates = dates + partial_dates

    # Filter out empty or whitespace strings and non-date-related strings
    filtered_dates = []
    year_counter = Counter()
    seen_dates = set()
    for date in all_dates:
        year_match = re.search(r'\b\d{4}\b', date)
        if year_match:
            year = year_match.group().strip()
            if year_counter[year] == 0 and date.lower() not in seen_dates:
                filtered_dates.append(date)
                year_counter[year] += 1
                seen_dates.add(date.lower())
        elif re.search(r'\b(?:January|February|March|April|May|June|July|August|September|October|November|December)\b', date):
            if date.lower() not in seen_dates:
                filtered_dates.append(date)
                seen_dates.add(date.lower())

    # Return the extracted dates without repeating years
    return filtered_dates

# %%
#THIS PART GETS THE MAIN LINK AND CREATES THE CSV COMBINING ALL THE FUNCTIONS FROM ABOVE
def extract_article_links(main_url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Mobile Safari/537.36'
    }

    r = requests.get(main_url, headers=headers)

    if r.status_code == 200:
        html_content = r.text
        soup = BeautifulSoup(html_content, 'html.parser')

        article_links = [a['href'] for a in soup.select('div.text-center a.blogpost-button')]

        return article_links

    else:
        print("Failed to fetch the main webpage. Status code:", r.status_code)
        return []

# Base URL of the website containing overviews of different articles
base_url = 'https://www.databreaches.net'

# Set up headers for the HTTP request
headers = {
    'User-Agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Mobile Safari/537.36'
}

# Define the start and end dates
start_date = date(2023, 2, 21)
end_date = date(2023, 1, 1)
delta = timedelta(days=1)

# Define the CSV file name
csv_file_name = 'data.csv'

# Open the CSV file in write mode
with open(csv_file_name, 'w', newline='', encoding='utf-8') as csvfile:
    # Define the CSV header
    fieldnames = ['Company Domain', 'Company Name', 'Company Industry', 'Date of Breach', 'Threat Actor', 'Article URL']

    # Create a CSV writer object
    csv_writer = csv.DictWriter(csvfile, fieldnames=fieldnames, delimiter='|')

    # Write the header to the CSV file
    csv_writer.writeheader()

    # Loop through the pages
    page_index = 271
    while True:
        # Construct the URL for the current page
        main_website_url = f"{base_url}/page/{page_index}/"

        try:
            # Fetch the main webpage
            r = requests.get(main_website_url, headers=headers)

            if r.status_code == 200:
                html_content = r.text
                soup = BeautifulSoup(html_content, 'html.parser')

                # Extract the article links from the current page
                article_links = [a['href'] for a in soup.select('div.text-center a.blogpost-button')]

                if not article_links:
                    # No more articles found, break the loop
                    break

                for article_link in article_links:
                    try:
                        # Fetch and process each article
                        r = requests.get(article_link, headers=headers)

                        if r.status_code == 200:
                            html_content = r.text

                            # Extracting the published date using the specified time class
                            published_date_element = BeautifulSoup(html_content, 'html.parser').find('time', class_='entry-date published updated') or BeautifulSoup(html_content, 'html.parser').find('time', class_='entry-date published')

                            if published_date_element:
                                # Convert the extracted string to a date object
                                published_date_str = published_date_element['datetime']
                                published_date = datetime.strptime(published_date_str, "%Y-%m-%dT%H:%M:%S%z").date()
                            else:
                                # Handle the case where the published date is not found
                                print(f"Published date not found in the article {article_link}. Skipping.")
                                continue

                            # Check if the published date is within the specified range
                            if end_date <= published_date <= start_date:
                                # Extract company info and other details (Don't Change or Touch)
                                company_name, company_domain = extract_company_info(html_content)
                                date_of_breach = extract_dates(html_content)
                                found_ransomware = find_ransomware_group(html_content, ransomware_groups)
                                company_industry = extract_company_industry(html_content, industry_keywords)

                                # Output Extracted Info
                                print("Writing to CSV:", company_name, company_domain, company_industry, date_of_breach, found_ransomware, published_date)
                                print("--------------------------------------")

                                # Write the data to the CSV file
                                csv_writer.writerow({
                                    'Article URL': article_link,
                                    'Company Domain': company_domain,
                                    'Company Name': company_name,
                                    'Company Industry': company_industry,
                                    'Date of Breach': date_of_breach,
                                    'Threat Actor': found_ransomware,
                                })

                            else:
                                print(f"Skipping article with URL {article_link} published on {published_date} as the published date is outside the specified range.")

                        else:
                            print(f"Failed to fetch the webpage {article_link}. Status code:", r.status_code)

                    except Exception as e:
                        print(f"An error occurred while processing the article {article_link}: {str(e)}")

                    # Delay to prevent excessive memory usage
                time.sleep(1)

            else:
                print(f"Failed to fetch the webpage {main_website_url}. Status code:", r.status_code)

        except Exception as e:
            print(f"An error occurred: {str(e)}")

        # Delay to prevent excessive memory usage
        # time.sleep(1)

        # Move to the next page
        page_index += 1
# Out:
# Skipping article with URL https://www.databreaches.net/chinese-security-researchers-claim-to-have-identified-against-the-west-hackers/ published on 2023-02-23 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/ks-hutchinson-clinic-issues-alert-concerning-december-data-breach/ published on 2023-02-23 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/north-korean-hackers-move-3-2m-from-gate-io-2018-hack/ published on 2023-02-23 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/l-a-unified-admits-that-at-least-2000-student-records-dumped-after-ransomware-attack/ published on 2023-02-23 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/cyberattack-on-food-giant-dole-temporarily-shuts-down-north-america-production-company-memo-says/ published on 2023-02-23 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/digital-healthcare-platform-ordered-to-pay-civil-penalties-and-take-corrective-action-for-unauthorized-disclosure-of-personal-health-information/ published on 2023-02-23 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/trove-of-l-a-students-mental-health-records-posted-to-dark-web-after-cyber-hack/ published on 2023-02-22 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/national-credit-union-administration-finalizes-72-hour-cyber-incident-reporting-rule/ published on 2023-02-22 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/lessons-from-a-ransomware-attack-the-importance-of-partnership-collaboration/ published on 2023-02-22 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/uk-meta-successfully-resists-certification-in-data-privacy-collective-action/ published on 2023-02-22 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/thoughts-on-dubin-v-united-states-and-the-aggravated-identity-theft-statute/ published on 2023-02-22 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/rehoboth-mckinley-christian-health-care-services-settles-data-breach-litigation-for-undisclosed-amount/ published on 2023-02-22 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/activision-did-not-notify-employees-of-data-breach-for-months/ published on 2023-02-22 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/uk-rail-ministers-laptop-with-confidential-details-of-strike-talks-is-stolen-from-pub/ published on 2023-02-22 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/washington-state-city-allegedly-hit-by-ransomware/ published on 2023-02-22 as the published date is outside the specified range.
# Writing to CSV: Ways And Means Committee Demands Investigation Into 2021 Taxpayer Info Leak None Unknown [] Ransomware 2023-02-21
# --------------------------------------
# Writing to CSV: Singapore Data Centre Says No Data Loss Discovered After Report On Hackers Obtaining Logins None Technology ['2021'] Ransomware 2023-02-21
# --------------------------------------
# Writing to CSV: HardBit securityaffairs.com Unknown ['October 2022', '2023'] Ransomware 2023-02-21
# --------------------------------------
# Writing to CSV: Protenus Releases Its 2023 Breach Barometer For Health Data Breaches None Technology ['January 1 of the year', 'December 31 of the year', '2022', '2021', '2023', 'January ', 'December '] Ransomware 2023-02-21
# --------------------------------------
# Writing to CSV: MN None Healthcare ['February 14', 'January 17, 2023', 'February 6', 'December 2021', 'February ', 'January '] Ransomware 2023-02-21
# --------------------------------------
# Writing to CSV: Hackers Start Selling Data Center Logins None Technology [] Ransomware 2023-02-21
# --------------------------------------
# Writing to CSV: Defending Data Breach Claims None Unknown ['February 17 2023', 'February 2021', 'February '] Ransomware 2023-02-21
# --------------------------------------
# Writing to CSV: Ca atlantic.ctvnews.ca Unknown [] Ransomware 2023-02-21
# --------------------------------------
# Writing to CSV: None None Healthcare ['January 9', 'February 11', '2015-2017', '1099', '1874', '2023', 'mid-2022', 'January ', 'February ', '2017'] 0Mega 2023-02-20
# --------------------------------------
# Writing to CSV: Lehigh Valley Health Network None Technology [] Ransomware 2023-02-20
# --------------------------------------
# Writing to CSV: NHS Workers None Healthcare [] Ransomware 2023-02-20
# --------------------------------------
# Writing to CSV: Fake Ethereum Denver Website Linked To Notorious Phishing Wallet None Unknown [] Ransomware 2023-02-20
# --------------------------------------
# Writing to CSV: Mscripts Notifies 66 None Healthcare ['January 17', 'between September 30, 2016', 'November 18, 2022', 'February 10, 2023', 'January ', 'September ', 'November ', 'February '] Ransomware 2023-02-19
# --------------------------------------
# Writing to CSV: Edgepark Medical Supplies None Healthcare ['February 3', 'November 14', 'December 2', 'December 5', 'February 10', 'February ', 'November ', 'December '] Ransomware 2023-02-19
# --------------------------------------
# Writing to CSV: Reventics Notifying Patients Of Ransomware Incident None Healthcare ['about December 15, 2022', 'December 27', 'February 10', 'February 13', 'February 23', 'February', 'December ', 'February '] Ransomware 2023-02-19
# --------------------------------------
# Writing to CSV: The Feds Are Launching A Hack Back Squad None Technology [] Ransomware 2023-02-18
# --------------------------------------
# Writing to CSV: Department Of Education To Enforce Revised Cybersecurity Requirements And Expands Interpretation Of None Technology ['December 9, 2021', 'December '] Ransomware 2023-02-18
# --------------------------------------
# Writing to CSV: Oops None Finance [] Ransomware 2023-02-18
# --------------------------------------
# Writing to CSV: Weeklong Ransomware Attack On Oakland Government Drags On None Unknown [] Ransomware 2023-02-18
# --------------------------------------
# Writing to CSV: NHS None Unknown ['June 2016', 'January 2017', '15 February 2023'] Ransomware 2023-02-18
# --------------------------------------
# Writing to CSV: Lancashire County Council None Finance [] Ransomware 2023-02-18
# --------------------------------------
# Writing to CSV: NHS Lothian None Unknown ['February 2021'] Ransomware 2023-02-18
# --------------------------------------
# Writing to CSV: Sweetwater Union High School District None Unknown [] Ransomware 2023-02-17
# --------------------------------------
# Writing to CSV: FBI edition.cnn.com Unknown [] Ransomware 2023-02-17
# --------------------------------------
# Writing to CSV: Unsecured Protected Health Information For None Finance ['calendar year 2020', '2021', '2022', '2023', 'July 2018', 'January ', 'December '] Ransomware 2023-02-17
# --------------------------------------
# Writing to CSV: Data Breach None Unknown ['2020-2021 school year', '2021'] Ransomware 2023-02-17
# --------------------------------------
# Writing to CSV: Godaddy www.bleepingcomputer.com Unknown ['early December 2022'] Ransomware 2023-02-17
# --------------------------------------
# Writing to CSV: Alaris www.bd.com Technology [] Ransomware 2023-02-17
# --------------------------------------
# Writing to CSV: Update To The Des Moines Public School Ransomware Attack None Unknown ['January 11', 'January 18', 'January '] Ransomware 2023-02-17
# --------------------------------------
# Writing to CSV: Spain Orders Extradition Of British Alleged Hacker To U None Unknown ['July 2020', 'July 2021'] Ransomware 2023-02-17
# --------------------------------------
# Writing to CSV: 150 Million None Unknown [] Ransomware 2023-02-17
# --------------------------------------
# Writing to CSV: Bits None Finance ['February 14th', 'February', '2020', 'early 2022', 'February '] Ransomware 2023-02-17
# --------------------------------------
# Writing to CSV: Norway Finds A Way To Recover Crypto North Korea Pinched In Axie Heist None Unknown [] Ransomware 2023-02-17
# --------------------------------------
# Writing to CSV: MKS Instruments None Healthcare ['February 13', 'February 16', 'February '] Ransomware 2023-02-16
# --------------------------------------
# Writing to CSV: Wawasee Community School Corporation None Technology ['January', 'January 23', 'January '] Ransomware 2023-02-16
# --------------------------------------
# Writing to CSV: Binance www.reuters.com Finance ['the first three months of 2021'] Ransomware 2023-02-16
# --------------------------------------
# Writing to CSV: DNA Diagnostics Center Stemming None Unknown ['between 2004 and 2012', 'May 2021', '2012'] Ransomware 2023-02-16
# --------------------------------------
# Writing to CSV: Private Data Breach Litigation Comes Of Age None Unknown ['2021', '2020', '3d 1197, 1212', '2014', '1212'] Ransomware 2023-02-16
# --------------------------------------
# Writing to CSV: Nice Try Tonto Team None Technology ['2023', '2022/2023'] Ransomware 2023-02-16
# --------------------------------------
# Writing to CSV: New Mortalkombat Ransomware And Laplas Clipper Malware Threats Deployed In Financially Motivated Campaign None Unknown ['December 2022', '3389'] Ransomware 2023-02-16
# --------------------------------------
# Writing to CSV: City Of Oakland Declares State Of Emergency After Ransomware Attack None Unknown ['February 8th', 'Wednesday, February 8', 'February '] Ransomware 2023-02-16
# --------------------------------------
# Writing to CSV: MySejahtera Data None Unknown ['2021', 'October ', 'November '] Ransomware 2023-02-16
# --------------------------------------
# Writing to CSV: A Major Global Chipmaking Supplier Claims An Employee Stole Manufacturing Secrets None Technology ['2022'] Ransomware 2023-02-16
# --------------------------------------
# Writing to CSV: California Northstate University None Unknown ['2022'] Ransomware 2023-02-15
# --------------------------------------
# Writing to CSV: GAO www.gao.gov Technology ['Feb 14, 2023', '2010', 'December 2022'] Ransomware 2023-02-15
# --------------------------------------
# Writing to CSV: SAS www.reuters.com Unknown [] Ransomware 2023-02-15
# --------------------------------------
# Writing to CSV: Cloudflare www.hackread.com Unknown [] Ransomware 2023-02-15
# --------------------------------------
# Writing to CSV: Healthcare www.bleepingcomputer.com Healthcare ['2023', '0669'] Ransomware 2023-02-15
# --------------------------------------
# Writing to CSV: Absurd techcrunch.com Unknown ['February 9', 'February '] Lockbit 2023-02-15
# --------------------------------------
# Writing to CSV: FL None Technology ['January 30', 'December', 'January '] Ransomware 2023-02-14
# --------------------------------------
# Writing to CSV: Second Verse None Healthcare ['January 27', 'November 30, 2022', 'July', 'November', 'January ', 'November ', 'July '] Ransomware 2023-02-14
# --------------------------------------
# Writing to CSV: FERPA None Unknown ['February 13', 'February 14', 'February '] Ransomware 2023-02-14
# --------------------------------------
# Writing to CSV: AZPC Clinics None Healthcare ['February 1', 'December 2', 'December 5', 'February ', 'December '] Ransomware 2023-02-14
# --------------------------------------
# Writing to CSV: Hackers Take Down Bahrain Airport Website None Unknown [] Ransomware 2023-02-14
# --------------------------------------
# Writing to CSV: New Picus Red Report None Unknown ['February 2023', '2022'] Ransomware 2023-02-14
# --------------------------------------
# Writing to CSV: Community Health Systems None Technology ['February 13', 'February '] Ransomware 2023-02-13
# --------------------------------------
# Writing to CSV: Pepsi Bottling Ventures None Unknown ['around December 23, 2022', 'December '] Ransomware 2023-02-13
# --------------------------------------
# Writing to CSV: Kimmel Center None Unknown [] Ransomware 2023-02-13
# --------------------------------------
# Writing to CSV: B&G Foods None Healthcare ['February 4', '2020', 'February '] Daixin 2023-02-12
# --------------------------------------
# Writing to CSV: And Two More Class Action Settlements None Unknown ['August 2021', 'June', 'January 3, 2023\nObjection', 'January ', 'March ', 'April ', 'June '] Ransomware 2023-02-12
# --------------------------------------
# Writing to CSV: Cop And Telecoms Staffer Charged In Data Breach Case None Telecommunications [] Ransomware 2023-02-12
# --------------------------------------
# Writing to CSV: Technion University None Technology [] Unknown 2023-02-12
# --------------------------------------
# Writing to CSV: Cybersecurity Incident Shuts Down Biglaw Network None Technology [] Ransomware 2023-02-11
# --------------------------------------
# Writing to CSV: Garrison Women’s Health None Technology ['about December 12, 2022', 'December 12', 'January 2-9, 2023', 'the April 29', 'December ', 'April ', 'January '] Ransomware 2023-02-11
# --------------------------------------
# Writing to CSV: Indian Social Media App Slick Exposed Childrens None Media and Entertainment ['at least December 11', 'December '] Ransomware 2023-02-11
# --------------------------------------
# Writing to CSV: Edmonds School District’s None Unknown ['May 16', 'May '] Ransomware 2023-02-11
# --------------------------------------
# Writing to CSV: Uyghurs None Unknown ['last May', 'May'] Ransomware 2023-02-11
# --------------------------------------
# Writing to CSV: BlackCat None Unknown ['February 5', 'February '] Ransomware 2023-02-11
# --------------------------------------
# Writing to CSV: City Of Oakland Targeted By Ransomware Attack None Technology ['February 10, 2023', 'February '] Ransomware 2023-02-10
# --------------------------------------
# Writing to CSV: Penang Government Data Leaked Online None Unknown [] Ransomware 2023-02-10
# --------------------------------------
# Writing to CSV: None None Unknown ['2023', '0669'] Clop 2023-02-10
# --------------------------------------
# Writing to CSV: Employee Personal Data Exposed In Nj School District Cyber Breach None Unknown ['December', 'the end of January', 'December ', 'January'] Ransomware 2023-02-10
# --------------------------------------
# Writing to CSV: Hack Attack Forces Modesto Police Off Computers None Unknown [] Ransomware 2023-02-10
# --------------------------------------
# Writing to CSV: Minneapolis Public Schools Was Nearly Conned Out Of None Unknown ['April 2020'] Ransomware 2023-02-10
# --------------------------------------
# Writing to CSV: UMass Memorial Health None Unknown ['June 24, 2020 to January 7, 2021', 'October 2021', 'June ', 'January ', '2185'] Ransomware 2023-02-10
# --------------------------------------
# Writing to CSV: Bits None Transportation ['February 5', 'February 2', 'February 1', 'February 6', 'January 27', 'February ', 'January '] Ransomware 2023-02-10
# --------------------------------------
# Writing to CSV: Dallas Central Appraisal District Paid None Unknown ['November 8, 2022', 'November '] Royal 2023-02-10
# --------------------------------------
# Writing to CSV: HIPAA None Finance ['January 24', 'January 2023', 'January '] Ransomware 2023-02-10
# --------------------------------------
# Writing to CSV: Cisa Alert None Technology ['the July 6, 2022', 'July '] Ransomware 2023-02-10
# --------------------------------------
# Writing to CSV: Hackers Breach Reddit To Steal Source Code And Internal Data None Unknown [] Ransomware 2023-02-10
# --------------------------------------
# Writing to CSV: Updates To The Gramm-leach-bliley Act Cybersecurity Requirements None Technology ['February 09, 2023', 'December 9, 2021', 'June 9', '1965', 'February 28, 2020', 'April of 2022', 'February ', 'December ', 'June ', 'April ', '2222', '6550'] Ransomware 2023-02-10
# --------------------------------------
# Writing to CSV: None None Unknown ['April 2020'] Ransomware 2023-02-10
# --------------------------------------
# Writing to CSV: Irent Fined For Data Leak None Transportation [] Ransomware 2023-02-09
# --------------------------------------
# Writing to CSV: Health Cards None Healthcare [] Ransomware 2023-02-09
# --------------------------------------
# Writing to CSV: VMware www.bleepingcomputer.com Unknown [] Ransomware 2023-02-09
# --------------------------------------
# Writing to CSV: Derriford Hospital None Healthcare [] Ransomware 2023-02-09
# --------------------------------------
# Writing to CSV: And U None Unknown [] Conti 2023-02-09
# --------------------------------------
# Writing to CSV: General Treasury None Unknown ['January 30', 'February 3', 'February 4', 'January ', 'February '] Ransomware 2023-02-09
# --------------------------------------
# Writing to CSV: Hk gbcode.rthk.hk Unknown ['December 2021'] Ransomware 2023-02-09
# --------------------------------------
# Writing to CSV: Insurers Say Cyberattack That Hit Merck Was Warlike Act None Unknown ['2017'] Ransomware 2023-02-09
# --------------------------------------
# Writing to CSV: NYS Comptroller DiNapoli None Technology ['January 27', '2023', 'July 1, 2020 – July 15, 2022', '2013-14', 'January ', 'July ', '2022'] Ransomware 2023-02-09
# --------------------------------------
# Writing to CSV: AmerisourceBergen MWI Animal Health None Unknown ['November 1', 'November '] Lorenz 2023-02-08
# --------------------------------------
# Writing to CSV: Hidalgo County Adult Probation Office None Unknown [] Ransomware 2023-02-08
# --------------------------------------
# Writing to CSV: DotHouse Health None Healthcare ['about December 10', 'January 27', 'late November', 'between October 21, 2022', 'about January 12', 'December ', 'January ', 'November', 'October ', 'November '] Ransomware 2023-02-08
# --------------------------------------
# Writing to CSV: Hackers Hit Vesuvius None Unknown [] Ransomware 2023-02-08
# --------------------------------------
# Writing to CSV: Graphiron www.bleepingcomputer.com Unknown ['at least October 2022', 'mid-January 2023', '0056'] Ransomware 2023-02-08
# --------------------------------------
# Writing to CSV: Ransomware None Unknown [] Ransomware 2023-02-08
# --------------------------------------
# Writing to CSV: Cisa Releases Recovery Tool For Vmware Ransomware Victims None Technology ['3800'] Ransomware 2023-02-08
# --------------------------------------
# Writing to CSV: Blue Cross Blue Shield None Media and Entertainment [] Ransomware 2023-02-07
# --------------------------------------
# Writing to CSV: Suspected Ransomware Attack Disables Some Systems At Ross Memorial Hospital None Technology ['Sunday, February 5', 'February '] Ransomware 2023-02-07
# --------------------------------------
# Writing to CSV: Russian E-commerce Giant Exposed Buyers None Retail ['1991', 'January 24', 'January '] Ransomware 2023-02-07
# --------------------------------------
# Writing to CSV: LUH highlandradio.com Healthcare [] Ransomware 2023-02-07
# --------------------------------------
# Writing to CSV: None None Unknown ['2019', '2021'] Clop 2023-02-07
# --------------------------------------
# Writing to CSV: Interpol www.scmp.com Technology [] Ransomware 2023-02-07
# --------------------------------------
# Writing to CSV: Knox College None Technology ['early December 2022', 'January', 'November ', 'December '] Ransomware 2023-02-07
# --------------------------------------
# Writing to CSV: Major Cybercrime Crackdown None Unknown [] Ransomware 2023-02-07
# --------------------------------------
# Writing to CSV: None None Unknown ['September 2022'] Lockbit 2023-02-07
# --------------------------------------
# Writing to CSV: Optus None Unknown ['September', 'November', '2000', 'September ', 'November '] Ransomware 2023-02-07
# --------------------------------------
# Writing to CSV: Sharp Notifies Nearly 63 None Healthcare ['January 12', 'between Aug. 12, 2021', 'Jan. 12, 2023', 'January '] Ransomware 2023-02-06
# --------------------------------------
# Writing to CSV: AMA www.insurancebusinessmag.com Unknown [] Ransomware 2023-02-06
# --------------------------------------
# Writing to CSV: Daylong 988 Suicide Line Outage Was Caused By Cyberattack None Technology ['December 1', 'December '] Ransomware 2023-02-06
# --------------------------------------
# Writing to CSV: Italy Warns Hackers Targeting Known Server Vulnerability None Technology [] Ransomware 2023-02-06
# --------------------------------------
# Writing to CSV: Cybersecurity Incident Under Investigation None Technology ['February 06', 'February '] Ransomware 2023-02-06
# --------------------------------------
# Writing to CSV: Aspire Surgical None Technology ['February 2', 'December 7, 2022', 'February ', 'December '] Ransomware 2023-02-05
# --------------------------------------
# Writing to CSV: Diligent Corp. None Healthcare ['June, 2022', 'May', 'February 2021', 'May 23', 'May 24', 'June', '1184', 'January 17 of this year', 'February 2', 'May ', 'January ', 'February '] Ransomware 2023-02-05
# --------------------------------------
# Writing to CSV: Highmark Health None Technology ['February 13', 'December 13, 2022', 'February 10', 'February ', 'December '] Ransomware 2023-02-05
# --------------------------------------
# Writing to CSV: A Tale Of Two Breach Notification Rules None Healthcare ['February 2023', '2009'] Ransomware 2023-02-05
# --------------------------------------
# Writing to CSV: FBI None Manufacturing [] Revil 2023-02-04
# --------------------------------------
# Writing to CSV: Four More Attacks On The Healthcare Sector None Healthcare ['Feb. 10, 2023', 'December 5, 2022', 'February 1', 'December 1', 'December 2', 'December 6', 'between November 23 and December 5', 'February 3', 'December ', 'November ', 'February '] Ransomware 2023-02-04
# --------------------------------------
# Writing to CSV: Taiwan Car Rental Platform Irent Plans Compensation For Data Leak Victims None Manufacturing [] Ransomware 2023-02-04
# --------------------------------------
# Writing to CSV: Microsoft blogs.microsoft.com Unknown [] Ransomware 2023-02-04
# --------------------------------------
# Writing to CSV: VMware www.bleepingcomputer.com Unknown ['23 February 2021', 'February 4, 2023', 'February '] Ransomware 2023-02-04
# --------------------------------------
# Writing to CSV: Edward Jones Sues To Stop Fired Advisor From Taking None Unknown ['January 26', 'January '] Ransomware 2023-02-04
# --------------------------------------
# Writing to CSV: Hackers www.reuters.com Unknown [] Ransomware 2023-02-04
# --------------------------------------
# Writing to CSV: TruthFinder www.bleepingcomputer.com Media and Entertainment ['2019'] Ransomware 2023-02-04
# --------------------------------------
# Writing to CSV: Julius therecord.media Unknown ['2015', 'November 2022'] Ransomware 2023-02-03
# --------------------------------------
# Writing to CSV: Bits None Telecommunications ['January 28', 'January 30', 'February 2', '2017', 'February 1', 'January ', 'February '] Ransomware 2023-02-03
# --------------------------------------
# Writing to CSV: Nonstop Health None Healthcare ['January 17 and 18', 'December, 2022', 'January 19', 'January 29', 'January 24 and January 29', 'June 2, 2023:', 'February', 'March', 'May 26', 'January', 'January ', 'December', 'June ', 'May ', 'February '] Ransomware 2023-02-03
# --------------------------------------
# Writing to CSV: FL None Technology ['2023'] Ransomware 2023-02-03
# --------------------------------------
# Writing to CSV: HHS www.hhs.gov Technology ['2016', '2019', 'February 02', '2023', '2021', 'February '] Ransomware 2023-02-03
# --------------------------------------
# Writing to CSV: British Columbia None Unknown ['February 1, 2023', 'November 2021', 'February '] Ransomware 2023-02-03
# --------------------------------------
# Writing to CSV: Uk ico.org.uk Unknown ['2019', 'January of that year', ' 2020', 'January '] Royal 2023-02-03
# --------------------------------------
# Writing to CSV: North Korean Hackers Stole Research Data In Two-month-long Breach None Technology ['between August and November 2022', 'August '] Ransomware 2023-02-03
# --------------------------------------
# Writing to CSV: Investigate Tax Companies Sharing Data None Unknown ['2022'] Ransomware 2023-02-03
# --------------------------------------
# Writing to CSV: LG Uplus None Unknown [] Ransomware 2023-02-03
# --------------------------------------
# Writing to CSV: Eight Arrested For Hacking Bank Accounts Using None Unknown [] Ransomware 2023-02-03
# --------------------------------------
# Writing to CSV: Credit Suisse None Unknown ['2022'] Ransomware 2023-02-03
# --------------------------------------
# Writing to CSV: Hackers Are Using This New Trick To Deliver Their Phishing Attacks None Unknown [] Ransomware 2023-02-03
# --------------------------------------
# Writing to CSV: Acuity Brands None Unknown [] Ransomware 2023-02-03
# --------------------------------------
# Writing to CSV: None None Healthcare ['September 2022', 'September 21', 'September 6', 'January 3', 'October 6', 'September 20', '2021', '2019', 'September', 'September ', 'November ', 'January ', 'October '] Ransomware 2023-02-02
# --------------------------------------
# Writing to CSV: Former Employee Ubiquiti Networks Pleads Guilty To Stealing Confidential Data And Extorting Company For Ransom None Technology ['about August 2018', 'about April 1, 2021', 'about December 2020', 'May 10, 2023', 'April ', 'March ', 'May '] Ransomware 2023-02-02
# --------------------------------------
# Writing to CSV: Au www.abc.net.au Unknown [] Ransomware 2023-02-02
# --------------------------------------
# Writing to CSV: Ie www.corkbeo.ie Finance ['the end of April', ' 2021', 'April'] Ransomware 2023-02-02
# --------------------------------------
# Writing to CSV: Auction Company Offers None Unknown ['July 23', 'July '] Ransomware 2023-02-01
# --------------------------------------
# Writing to CSV: FTC Enforcement Action None Healthcare ['January 2017', 'August 2019', 'February 2020', 'September 2021', ' 1996'] Ransomware 2023-02-01
# --------------------------------------
# Writing to CSV: Skyview Networks Suffers Security Incident None Unknown [] Ransomware 2023-02-01
# --------------------------------------
# Writing to CSV: Uk www.farrer.co.uk Unknown [] Ransomware 2023-02-01
# --------------------------------------
# Writing to CSV: In 2023 None Technology ['2023', '2022'] Ransomware 2023-02-01
# --------------------------------------
# Writing to CSV: Yandex Data Breach Reveals Source Code Littered With Racist Language None Unknown ['26 January', 'January'] Ransomware 2023-02-01
# --------------------------------------
# Writing to CSV: GitHub github.blog Unknown ['December 6, 2022', 'December '] Ransomware 2023-02-01
# --------------------------------------
# Writing to CSV: Microsoft www.bleepingcomputer.com Unknown [] Ransomware 2023-02-01
# --------------------------------------
# Writing to CSV: Google Fi Customers Caught Up None Unknown [] Ransomware 2023-02-01
# --------------------------------------
# Writing to CSV: Hacker Finds Bug That Allowed Anyone To Bypass Facebook 2fa None Unknown [] Ransomware 2023-02-01
# --------------------------------------
# Writing to CSV: Morgan Hill Unified School District None Unknown ['between September 11 and October 11, 2022', 'January 27', '2021-2022 school year', 'September ', 'October ', 'January '] Ransomware 2023-02-01
# --------------------------------------
# Writing to CSV: Raoult None Unknown ['January 17', 'January 25', 'April 3, 3023', 'January ', 'April '] Ransomware 2023-01-31
# --------------------------------------
# Writing to CSV: Hc3 None Healthcare ['January 30, 2023\nTLP', 'at least January 2022', 'January '] Ransomware 2023-01-31
# --------------------------------------
# Writing to CSV: Ransomware Attack On Appui None Unknown [] Ransomware 2023-01-31
# --------------------------------------
# Writing to CSV: Nantucket Public Schools Closed Following Ransomware Attack None Unknown ['January'] Ransomware 2023-01-31
# --------------------------------------
# Writing to CSV: IR securityboulevard.com Unknown ['January 9, 2023', '21-1397', 'January '] Ransomware 2023-01-31
# --------------------------------------
# Writing to CSV: TUSD tucson.com Technology ['February 10, 2023', 'February '] Ransomware 2023-01-30
# --------------------------------------
# Writing to CSV: Qulliq Energy None Technology ['January'] Ransomware 2023-01-30
# --------------------------------------
# Writing to CSV: Atlantic General Hospital None Healthcare [] Ransomware 2023-01-30
# --------------------------------------
# Writing to CSV: Bits None Education ['January 21', 'January 23', 'January 22', 'January 24', 'January 20', 'January '] Ransomware 2023-01-30
# --------------------------------------
# Writing to CSV: Jd Sports Hit By Cyber-attack That Accessed 10m Customers None Unknown ['between November 2018 and October 2020', 'October 2020'] Ransomware 2023-01-30
# --------------------------------------
# Writing to CSV: Kremlin www.reuters.com Technology ['2021'] Ransomware 2023-01-30
# --------------------------------------
# Writing to CSV: Doctor Paid None Unknown [] Ransomware 2023-01-30
# --------------------------------------
# Writing to CSV: Why Is No One Ever Penalised For Data Breaches In India None Technology [] Ransomware 2023-01-30
# --------------------------------------
# Writing to CSV: Healthcare Software None Healthcare ['October 2022', '2018'] Ransomware 2023-01-29
# --------------------------------------
# Writing to CSV: Class Action Lawsuits Following Breaches In The Medical Sector None Technology ['2023', 'September 2021', '2019', '0108'] Ransomware 2023-01-28
# --------------------------------------
# Writing to CSV: Jm None Technology ['January 11', 'January '] Ransomware 2023-01-28
# --------------------------------------
# Writing to CSV: Zacks Investment Research None Unknown ['between November 2021', 'August 2022'] Ransomware 2023-01-28
# --------------------------------------
# Writing to CSV: Stratford University None Unknown ['September 2022', 'September 8', 'August', 'August 17', 'August 26', 'January 15, 2023', 'September 7', 'September ', 'August ', 'April ', 'January '] Ransomware 2023-01-27
# --------------------------------------
# Writing to CSV: Lutheran Social Services Of Illinois Notifies 184 None Unknown ['March 25, 2022', 'January 25, 2023', 'December 31, 2021 to January 27, 2022', 'March ', 'January ', 'December '] Ransomware 2023-01-27
# --------------------------------------
# Writing to CSV: Indianapolis Housing Authority None Unknown ['early October', 'October 4', 'September 23', 'October', 'October ', 'September '] Ransomware 2023-01-27
# --------------------------------------
# Writing to CSV: Alleged French Cybercriminal To Appear In Seattle On Friday On Indictment For Conspiracy None Finance ['tomorrow January 27, 2023', 'June 23, 2021', 'early 2020', 'January ', 'June '] Ransomware 2023-01-26
# --------------------------------------
# Writing to CSV: S Infrastructure Seized None Healthcare ['2021', 'July of 2022', 'July '] Hive 2023-01-26
# --------------------------------------
# Writing to CSV: Developing None Unknown ['January 26, 2023', 'January '] Hive 2023-01-26
# --------------------------------------
# Writing to CSV: Baltimore Schools Cyber Attack Cost Nearly None Technology ['November 2020', '2008', '2015', '21-0001', '2023'] Ransomware 2023-01-26
# --------------------------------------
# Writing to CSV: Ncsc www.computing.co.uk Unknown [] Ransomware 2023-01-26
# --------------------------------------
# Writing to CSV: Bloke Allegedly Stole None Unknown [] Ransomware 2023-01-26
# --------------------------------------
# Writing to CSV: French National Extradited To U None Unknown ['May 31', 'May '] Ransomware 2023-01-25
# --------------------------------------
# Writing to CSV: Ransomware www.lemagit.fr Technology ['2021', 'June 2022'] Ransomware 2023-01-25
# --------------------------------------
# Writing to CSV: Credit Suisse AG None Unknown ['January 20', 'about January 1, 2016', 'December 21, 2022', 'January ', 'December '] Ransomware 2023-01-25
# --------------------------------------
# Writing to CSV: In None Unknown [] Ransomware 2023-01-25
# --------------------------------------
# Writing to CSV: Nist Requests Comments On Potential Significant Updates To The Cybersecurity Framework None Technology ['January 19, 2023', '2014', '2018', 'January '] Ransomware 2023-01-25
# --------------------------------------
# Writing to CSV: Australian Man Given Two-year Jail Sentence For None Unknown [] Ransomware 2023-01-25
# --------------------------------------
# Writing to CSV: GodMode 9to5mac.com Unknown ['2020', 'October'] Ransomware 2023-01-25
# --------------------------------------
# Writing to CSV: Court Records Were Lost In Debilitating Vanuatu Cyber Attack None Unknown ['the end of October 2022', 'November and December', 'November', 'November ', 'December'] Ransomware 2023-01-25
# --------------------------------------
# Writing to CSV: TFT www.timesnownews.com Unknown [] Ransomware 2023-01-25
# --------------------------------------
# Writing to CSV: Puma Investigates Claims Of Leaking More Than 230k Customers None Retail ['January 21, 2023', 'January '] Ransomware 2023-01-24
# --------------------------------------
# Writing to CSV: LastPass techcrunch.com Unknown ['November 30', 'August', '2015', 'November ', 'August '] Ransomware 2023-01-24
# --------------------------------------
# Writing to CSV: Data Breach Reporting Requirements None Unknown ['February 22, 2023', '3953-3965', 'February ', 'March ', '3965'] Ransomware 2023-01-24
# --------------------------------------
# Writing to CSV: Ticketmaster www.politico.com Unknown ['November', 'November '] Ransomware 2023-01-24
# --------------------------------------
# Writing to CSV: FBI www.fbi.gov Unknown ['2022'] Ransomware 2023-01-24
# --------------------------------------
# Writing to CSV: Byng Public Schools None Technology [] Ransomware 2023-01-23
# --------------------------------------
# Writing to CSV: Ca None Unknown [] Ransomware 2023-01-23
# --------------------------------------
# Writing to CSV: India www.wired.com Education ['2017'] Ransomware 2023-01-23
# --------------------------------------
# Writing to CSV: FanDuels www.bleepingcomputer.com Unknown ['January 2023', 'January 13th', 'January '] Ransomware 2023-01-23
# --------------------------------------
# Writing to CSV: None None Media and Entertainment ['2019'] Ransomware 2023-01-23
# --------------------------------------
# Writing to CSV: Nhs Is The Most Phished Uk Government Organization None Unknown ['2022', '2023'] Ransomware 2023-01-22
# --------------------------------------
# Writing to CSV: Private Health Data Breach In Isle Of Man To Be Dealt Within 3 Months None Unknown ['2021'] Ransomware 2023-01-22
# --------------------------------------
# Writing to CSV: Impact Of Ransomware On Healthcare None Technology [] Ransomware 2023-01-22
# --------------------------------------
# Writing to CSV: TSA www.foxbusiness.com Transportation ['2019'] Ransomware 2023-01-22
# --------------------------------------
# Writing to CSV: Rundle Eye Care None Unknown ['early October', 'January 11', 'October', 'early October 2022', 'October 25, Everest', 'October 25', 'February 3', 'January 12, 2023', 'January ', 'October ', 'February '] Ransomware 2023-01-21
# --------------------------------------
# Writing to CSV: BlackCat None Technology ['January 17', 'January 19', 'January 20', 'January '] Ransomware 2023-01-21
# --------------------------------------
# Writing to CSV: Lausd Says Vice Society Ransomware Gang Stole Contractors None Unknown ['between July 31, 2022', 'July ', 'September '] Ransomware 2023-01-21
# --------------------------------------
# Writing to CSV: DCH Health System None Unknown ['December 2022', 'September 2021', ' 2500'] Ransomware 2023-01-21
# --------------------------------------
# Writing to CSV: SSN None Unknown [] Ransomware 2023-01-20
# --------------------------------------
# Writing to CSV: Ransomware Revenue Falls None Technology ['2022'] Ransomware 2023-01-20
# --------------------------------------
# Writing to CSV: Odin Intelligence Website Is Defaced As Hackers Claim Breach None Technology ['January 17', 'Between January 5, 2023 – January 10, 2023', 'January '] Ransomware 2023-01-20
# --------------------------------------
# Writing to CSV: St. Rose Hospital None Healthcare ['January 12', 'December 29, 2022', 'December 29', 'January ', 'December ', 'November '] Ransomware 2023-01-20
# --------------------------------------
# Writing to CSV: Bits None Technology ['2022'] Ransomware 2023-01-20
# --------------------------------------
# Writing to CSV: T-mobile Discloses Yet Another Data Breach None Unknown ['late November', 'January 5', 'November ', 'January '] Ransomware 2023-01-20
# --------------------------------------
# Writing to CSV: Chinese www.securityweek.com Unknown ['2022'] Ransomware 2023-01-20
# --------------------------------------
# Writing to CSV: More Than 19 None Unknown ['Jan. 17, 2023'] Ransomware 2023-01-20
# --------------------------------------
# Writing to CSV: Uk www.varsity.co.uk Unknown [] Ransomware 2023-01-20
# --------------------------------------
# Writing to CSV: KFC www.bleepingcomputer.com Unknown [] Ransomware 2023-01-20
# --------------------------------------
# Writing to CSV: ICE news.yahoo.com Unknown ['late November', 'November'] Ransomware 2023-01-19
# --------------------------------------
# Writing to CSV: NHIA None Healthcare [] Ransomware 2023-01-19
# --------------------------------------
# Writing to CSV: 34 None Technology ['December 20, 2022', 'December ', '1348'] Ransomware 2023-01-19
# --------------------------------------
# Writing to CSV: New Cybersecurity Directives None Technology ['January 16, 2023', 'January '] Ransomware 2023-01-19
# --------------------------------------
# Writing to CSV: Mailchimp Says It Was Hacked None Unknown ['January 11', 'January '] Ransomware 2023-01-19
# --------------------------------------
# Writing to CSV: Russia-linked Drug Marketplace Solaris Hacked By Its Rival None Unknown ['January 13', 'January '] Ransomware 2023-01-19
# --------------------------------------
# Writing to CSV: Ph None Unknown ['2022', 'September '] Ransomware 2023-01-18
# --------------------------------------
# Writing to CSV: MN None Unknown ['November 2020', 'December 30th', ' 1600', 'December '] Ransomware 2023-01-18
# --------------------------------------
# Writing to CSV: HHS www.hhs.gov Technology [] Royal 2023-01-18
# --------------------------------------
# Writing to CSV: NYS Comptroller None Technology ['December 30, 2022', '2020', 'December 20, 2021\n', 'December ', 'July '] Ransomware 2023-01-18
# --------------------------------------
# Writing to CSV: Ships gcaptain.com Transportation ['Saturday, January 7', 'January '] Ransomware 2023-01-18
# --------------------------------------
# Writing to CSV: GDPR www.dlapiper.com Unknown ['2021'] Ransomware 2023-01-18
# --------------------------------------
# Writing to CSV: Bank Of Thailand Blames Dating App For Phone Hacking None Media and Entertainment [] Ransomware 2023-01-18
# --------------------------------------
# Writing to CSV: Ransomware Diaries None Unknown [] Lockbit 2023-01-16
# --------------------------------------
# Writing to CSV: Wa None Unknown ['December 2 to December 4, 2022', '1975', '2001', 'December '] Ransomware 2023-01-16
# --------------------------------------
# Writing to CSV: None None Healthcare [] Mallox 2023-01-16
# --------------------------------------
# Writing to CSV: Hacked Evidence And Stolen Data Swamp English Courts None Unknown ['November', 'November '] Ransomware 2023-01-16
# --------------------------------------
# Writing to CSV: None None Unknown ['the summer of\xa02022'] Bianlian 2023-01-16
# --------------------------------------
# Writing to CSV: North Korean Hacking Group Tied None Unknown [] Ransomware 2023-01-16
# --------------------------------------
# Writing to CSV: Password www.bleepingcomputer.com Unknown [] Ransomware 2023-01-16
# --------------------------------------
# Writing to CSV: NY nypost.com Healthcare ['2023'] Ransomware 2023-01-15
# --------------------------------------
# Writing to CSV: FCC www.fcc.gov Telecommunications [] Ransomware 2023-01-15
# --------------------------------------
# Writing to CSV: Le Mans Virtual None Unknown ['June'] Ransomware 2023-01-15
# --------------------------------------
# Writing to CSV: Sorry None Unknown ['August 2021', '2013', '2016'] Ransomware 2023-01-15
# --------------------------------------
# Writing to CSV: None None Unknown [] Lockbit 2023-01-14
# --------------------------------------
# Writing to CSV: The Unexpected Effect Of The Introduction Of Mandatory Breach Notification Requirements In None Unknown ['September 22, 2022', 'September 22, 2023', 'September ', 'November '] Ransomware 2023-01-14
# --------------------------------------
# Writing to CSV: Home Care Providers None Unknown ['between June 25 and June 29', 'June 29', 'June '] Ransomware 2023-01-13
# --------------------------------------
# Writing to CSV: CL0P None Unknown ['mid-December', 'December '] Ransomware 2023-01-13
# --------------------------------------
# Writing to CSV: Bits None Technology ['January 11', 'January 11, 2023', 'January 10', 'January 2', 'January 12', 'December 30', 'January ', 'December '] Ransomware 2023-01-13
# --------------------------------------
# Writing to CSV: Okanagan College None Technology ['January 12', 'Jan 12, 2023', 'January ', '2435', '3879', '4574'] Ransomware 2023-01-13
# --------------------------------------
# Writing to CSV: None None Unknown [] Lorenz 2023-01-13
# --------------------------------------
# Writing to CSV: A Police App Exposed Secret Details About Raids And Suspects None Unknown ['Last September', 'September'] Ransomware 2023-01-12
# --------------------------------------
# Writing to CSV: SEC fingfx.thomsonreuters.com Unknown ['November 2020'] Ransomware 2023-01-12
# --------------------------------------
# Writing to CSV: Aflac Insurance None Finance [] Ransomware 2023-01-12
# --------------------------------------
# Writing to CSV: Ransomware Attack Exposes California Transit Giant None Technology [] Ransomware 2023-01-12
# --------------------------------------
# Writing to CSV: Guardian www.theguardian.com Unknown ['December', 'December '] Ransomware 2023-01-11
# --------------------------------------
# Writing to CSV: Update About An Alleged Incident Regarding Twitter User Data Being Sold Online None Unknown ['August 2022', 'June 2021', 'January 2023', 'November', 'November '] Ransomware 2023-01-11
# --------------------------------------
# Writing to CSV: TX None Unknown ['November 7', 'November '] Ransomware 2023-01-11
# --------------------------------------
# Writing to CSV: NYS DFS Announces None Technology ['January 4', '2017', 'late 2021', 'early 2022', 'January '] Ransomware 2023-01-11
# --------------------------------------
# Writing to CSV: A Government Watchdog Spent None Technology [] Ransomware 2023-01-11
# --------------------------------------
# Writing to CSV: Trooper www.wusa9.com Unknown [] Ransomware 2023-01-11
# --------------------------------------
# Writing to CSV: Captify None Unknown ['mid-December', '2019', 'March of 2021', 'mid-October 2022', 'December ', 'March ', 'May ', 'April '] Ransomware 2023-01-10
# --------------------------------------
# Writing to CSV: Identity Thieves Bypassed Experian Security None Unknown ['the end of 2022'] Ransomware 2023-01-10
# --------------------------------------
# Writing to CSV: Email Reveals Ar-15 Pistol Brace Company Hit With Data Breach Ahead Of Atf Ruling None Unknown [] Ransomware 2023-01-10
# --------------------------------------
# Writing to CSV: Toronto Hospital Network Issues None Healthcare [] Ransomware 2023-01-10
# --------------------------------------
# Writing to CSV: Des Moines Public Schools Cancels Tuesday Classes After Cybersecurity Attack None Technology [] Ransomware 2023-01-09
# --------------------------------------
# Writing to CSV: Oxford University None Unknown [] Ransomware 2023-01-09
# --------------------------------------
# Writing to CSV: When Ransom Negotiations Become Public None Unknown ['December 15', 'October', 'December '] Ransomware 2023-01-09
# --------------------------------------
# Writing to CSV: Oregon Workers None Technology ['October', 'October 24', '2003', 'between September 24, 2022', 'October ', 'January ', 'September '] Ransomware 2023-01-09
# --------------------------------------
# Writing to CSV: What Twitter None Unknown ['the end of 2022', 'June 2021'] Ransomware 2023-01-08
# --------------------------------------
# Writing to CSV: Slack’s None Unknown [] Ransomware 2023-01-08
# --------------------------------------
# Writing to CSV: Social Security Numbers None Unknown ['January 6', 'January '] Ransomware 2023-01-08
# --------------------------------------
# Writing to CSV: FCC docs.fcc.gov Telecommunications ['January 6, 2023', 'January '] Ransomware 2023-01-08
# --------------------------------------
# Writing to CSV: Man Who Got Into Hacking While Still In School Explains What He Did In Anonymous None Unknown [] Ransomware 2023-01-07
# --------------------------------------
# Writing to CSV: Air France None Hospitality [] Ransomware 2023-01-07
# --------------------------------------
# Writing to CSV: Consulate Health Care None Healthcare ['December 3', 'early December', 'December 3 lock date', '2011', '2012', '2017', 'March 2021', 'September', 'December ', '1000'] Hive 2023-01-06
# --------------------------------------
# Writing to CSV: Hc3 None Unknown ['January 04', '2019', 'January ', '2023'] Clop 2023-01-06
# --------------------------------------
# Writing to CSV: Bits None Media and Entertainment [] Ransomware 2023-01-06
# --------------------------------------
# Writing to CSV: Russian Hackers Targeted U None Unknown ['Between August and September', 'August ', 'September'] Ransomware 2023-01-06
# --------------------------------------
# Writing to CSV: Uk www.bbc.com Unknown ['2021 & 2022', '2022'] Ransomware 2023-01-06
# --------------------------------------
# Writing to CSV: VIC www.kalminer.com.au Unknown ['December'] Ransomware 2023-01-05
# --------------------------------------
# Writing to CSV: Districts Victimized None Technology ['October 2022', ' 2023'] Ransomware 2023-01-05
# --------------------------------------
# Writing to CSV: University Of Miami Health Breach Notice None Unknown [] Ransomware 2023-01-05
# --------------------------------------
# Writing to CSV: Pa None Healthcare ['January 3, 2023', 'April 4, 2022', 'August 21, 2021', 'April', 'January ', 'April ', 'August '] Ransomware 2023-01-05
# --------------------------------------
# Writing to CSV: Romanian Hospital Victim Of Ransomware Attack None Healthcare ['December', 'the summer of 2019', 'December '] Ransomware 2023-01-05
# --------------------------------------
# Writing to CSV: Jp www3.nhk.or.jp Unknown [] Ransomware 2023-01-04
# --------------------------------------
# Writing to CSV: ANPD Updates Information Security Incident Notification Guidelines None Unknown ['January 1, 2023', 'January '] Ransomware 2023-01-04
# --------------------------------------
# Writing to CSV: Swansea Public Schools Cancel Classes Wednesday After Ransomware Attack None Unknown [] Ransomware 2023-01-04
# --------------------------------------
# Writing to CSV: Hc3 None Healthcare ['December 22, 2022\n', 'December '] Ransomware 2023-01-03
# --------------------------------------
# Writing to CSV: Just Snarky Or Dangerous None Unknown [] Ransomware 2023-01-03
# --------------------------------------
# Writing to CSV: Why Do Ransomware Victims Pay For Data Deletion Guarantees None Unknown [] Ransomware 2023-01-03
# --------------------------------------
# Writing to CSV: New Data Quantifies Ransomware Attacks None Technology ['2016-2021', '2021'] Ransomware 2023-01-03
# --------------------------------------
# Writing to CSV: Ransomware None Healthcare ['December 21', 'December 30', 'December '] Hive 2023-01-02
# ...
# Skipping article with URL https://www.databreaches.net/connectwise-quietly-patches-flaw-that-helps-phishers/ published on 2022-12-03 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/nl-forum-voor-democratie-data-leak-leaves-93000-members-and-former-members-exposed/ published on 2022-12-03 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/darknet-markets-generate-millions-in-revenue-selling-stolen-personal-data/ published on 2022-12-03 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/florida-state-tax-website-bug-exposed-filers-data/ published on 2022-12-03 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/we-werent-ready-inside-st-michael-medical-center-during-october-cyberattack-outages/ published on 2022-12-02 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/cybersecurity-incident-hits-san-diego-unified-computer-network/ published on 2022-12-02 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/dhs-cyber-safety-review-board-to-conduct-second-review-on-lapsus/ published on 2022-12-02 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/in-hackers-selling-personal-data-of-150000-patients-from-a-tamil-nadu-hospital-in-supply-chain-attack/ published on 2022-12-02 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/bits-n-pieces-trozos-y-piezas-18/ published on 2022-12-02 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/australia-will-now-fine-firms-up-to-au50-million-for-data-breaches/ published on 2022-12-02 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/ca-vancouver-film-school-hit-by-paralyzing-cyberattack/ published on 2022-12-02 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/source-fbi-investigating-cyberattack-of-online-sportsbooks/ published on 2022-12-02 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/unknown-hacker-makes-away-with-5-million-from-ankr-protocol/ published on 2022-12-02 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/little-rock-school-district-reports-data-security-incident/ published on 2022-12-01 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/privacy-breach-reported-by-manitoba-health/ published on 2022-12-01 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/new-zealand-health-insurer-accuro-says-its-been-hacked-cant-rule-out-customers-data-being-accessed/ published on 2022-12-01 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/stopransomware-cuba-ransomware/ published on 2022-12-01 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/brazilian-debt-collection-firm-pays-hive-500k-ransom-while-suspectfile-spectates-it-all/ published on 2022-12-01 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/albanian-it-staff-charged-with-negligence-over-cyberattack/ published on 2022-12-01 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/vanuatu-officials-turn-to-phone-books-and-typewriters-one-month-after-cyber-attack/ published on 2022-12-01 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/hackers-are-locking-out-mars-stealer-operators-from-their-own-servers/ published on 2022-12-01 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/nj-internet-issues-caused-by-unauthorized-third-party-close-south-jersey-school/ published on 2022-12-01 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/ca-personal-info-of-5000-edmonton-employees-compromised-in-insider-data-breach/ published on 2022-12-01 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/nz-unfortunate-and-regrettable-incident-inside-the-otago-university-data-breach/ published on 2022-12-01 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/the-popes-website-taken-offline-in-suspected-hacker-attack/ published on 2022-12-01 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/ice-accidentally-released-the-identities-of-6252-immigrants-who-sought-protection-in-the-u-s/ published on 2022-11-30 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/de-klinikum-lippe-hospital-decrypts-data-after-intensive-negotiations-with-ransomware-attackers/ published on 2022-11-30 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/lastpasss-august-incident-contributed-to-a-new-incident/ published on 2022-11-30 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/sandworm-gang-launches-monster-ransomware-attacks-on-ukraine/ published on 2022-11-30 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/nurse-removed-confidential-patient-files-from-three-nursing-homes-in-cork-and-kerry/ published on 2022-11-30 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/connexin-software-notifies-parents-of-2-2-million-pediatric-patients-of-hack/ published on 2022-11-30 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/one-brooklyn-health-system-offline-for-more-than-one-week-has-it-been-hit-with-ransomware/ published on 2022-11-30 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/liability-for-cyber-attacks-clarified-by-ontario-court-of-appeal/ published on 2022-11-30 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/trigona-ransomware-spotted-in-increasing-attacks-worldwide/ published on 2022-11-30 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/ga-federal-magistrate-judge-recommends-dismissing-hacking-case-against-vikas-singla/ published on 2022-11-29 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/update-one-week-later-all-india-institute-of-medical-sciences-aiims-services-still-on-manual-system/ published on 2022-11-29 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/dod-releases-path-to-cyber-security-through-zero-trust-architecture/ published on 2022-11-29 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/au-significantly-larger-privacy-breach-fines-pass-parliament/ published on 2022-11-29 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/in-crown-point-community-school-corp-students-to-return-to-school-tuesday/ published on 2022-11-28 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/developing-data-from-kenosha-unified-school-district-shows-up-on-dark-web/ published on 2022-11-28 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/irelands-data-protection-commission-announces-decision-in-facebook-data-scraping-inquiry/ published on 2022-11-28 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/ca-ddsb-recovering-from-cyber-attack-that-left-schools-without-access-to-email-or-emergency-contact-information/ published on 2022-11-28 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/5-4-million-twitter-users-stolen-data-leaked-online-more-shared-privately/ published on 2022-11-27 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/whatsapp-dismisses-report-of-alleged-data-leak-containing-phone-numbers-of-nearly-3-million-hongkongers/ published on 2022-11-27 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/in-new-hampshire-school-technology-directors-collaborate-to-protect-student-data/ published on 2022-11-27 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/russian-hackers-target-dutch-lng-terminal/ published on 2022-11-27 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/iran-blames-israel-for-fars-news-agency-hack/ published on 2022-11-27 as the published date is outside the specified range.
# Skipping article with URL https://www.databreaches.net/reminder-that-small-n-medical-privacy-breaches-can-cause-harm/ published on 2022-11-26 as the published date is outside the specified range.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 72
#      69 for article_link in article_links:
#      70     try:
#      71         # Fetch and process each article
# ---> 72         r = requests.get(article_link, headers=headers)
#      74         if r.status_code == 200:
#      75             html_content = r.text
#
# File ~\PycharmProjects\webScraper\venv\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\PycharmProjects\webScraper\venv\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\PycharmProjects\webScraper\venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\PycharmProjects\webScraper\venv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\PycharmProjects\webScraper\venv\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~\PycharmProjects\webScraper\venv\Lib\site-packages\urllib3\connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File ~\PycharmProjects\webScraper\venv\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~\PycharmProjects\webScraper\venv\Lib\site-packages\urllib3\connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File C:\Python311\Lib\http\client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File C:\Python311\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File C:\Python311\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File C:\Python311\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File C:\Python311\Lib\ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File C:\Python311\Lib\ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:
